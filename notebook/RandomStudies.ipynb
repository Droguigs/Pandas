# %%
import pandas as pd

# %%
df = pd.read_csv("annual-enterprise-survey-2021-financial-year-provisional-csv.csv", index_col = "Industry_code_ANZSIC06")

# %%
df.head(5)
# Out:
#                                                     Year  \
# Industry_code_ANZSIC06
# ANZSIC06 divisions A-S (excluding classes K6330...  2021
# ANZSIC06 divisions A-S (excluding classes K6330...  2021
# ANZSIC06 divisions A-S (excluding classes K6330...  2021
# ANZSIC06 divisions A-S (excluding classes K6330...  2021
# ANZSIC06 divisions A-S (excluding classes K6330...  2021
#
#                                                    Industry_aggregation_NZSIOC  \
# Industry_code_ANZSIC06
# ANZSIC06 divisions A-S (excluding classes K6330...                     Level 1
# ANZSIC06 divisions A-S (excluding classes K6330...                     Level 1
# ANZSIC06 divisions A-S (excluding classes K6330...                     Level 1
# ANZSIC06 divisions A-S (excluding classes K6330...                     Level 1
# ANZSIC06 divisions A-S (excluding classes K6330...                     Level 1
#
#                                                    Industry_code_NZSIOC  \
# ...
